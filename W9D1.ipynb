# %%
num_studenti = 25

# %%
print(num_studenti)
# Out:
# 25

# %%
num_studenti_2 = 3
num_studenti_3 = num_studenti + num_studenti_2
print(num_studenti_3)
# Out:
# 28

# %%
str_epicode = "Epicode"
print(str_epicode)
# Out:
# Epicode

# %%
x = 10
print(x)
x += 2
print(x)
x *= 3
print(x)
# Out:
# 10
# 12
# 36

# %%
str1 = "Windows"
str2 = "Excel"
str3 = "Powerpoint"
str4 = "Word"
print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))
# Out:
# 7
# 5
# 10
# 4

# %%
day_in_year = 365
hours_in_day = 24
minutes_in_hour = 60
seconds_in_minute = 60

seconds_in_year = day_in_year * hours_in_day * minutes_in_hour * seconds_in_minute

print(f"I secondi in un anno non bisestile sono: {seconds_in_year}")
# Out:
# I secondi in un anno non bisestile sono: 31536000

# %%
my_string = "I am studying Python"
print(my_string)
my_string = my_string.upper()
print(my_string)
my_string = my_string.lower()
print(my_string)
my_string = my_string.replace("Python", "a lot") #la stringa rimane invariata in quanto "Python" ha la 'P' maiuscola
print(my_string)
my_string = my_string.strip() #la stringa rimane invariata in quanto non ci sono spazi a inizio o fine
print(my_string)
print(my_string.split())
# Out:
# I am studying Python
# I AM STUDYING PYTHON
# i am studying python
# i am studying python
# i am studying python
# ['i', 'am', 'studying', 'python']

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

corsi.append("Frontend")
corsi.append("Cybersecurity")
